# %%
import os
import pandas as pd

# %%
os.listdir('../data')
# Out:
# ['июль-ноябрь',
#  'результат с фото',
#  'Результаты 19-20',
#  'результаты 07.19-31.03 - с фото']

# %%
l1 = os.listdir('../data/июль-ноябрь/')
l2 = os.listdir('../data/результат с фото/')
l3 = os.listdir('../data/Результаты 19-20/')
l4 = os.listdir('../data/результаты 07.19-31.03 - с фото/октябрь-декабрь')
l5 = os.listdir('../data/результаты 07.19-31.03 - с фото/январь-март')
l6 = os.listdir('../data/результаты 07.19-31.03 - с фото/июль-сентябрь')

df = pd.DataFrame({'l1':l1, 'l2':l2, 'l3':l3, 'l4':l4, 'l5':l5, 'l6':l6})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-cc96343efd06> in <module>
#       6 l6 = os.listdir('../data/результаты 07.19-31.03 - с фото/июль-сентябрь')
#       7
# ----> 8 df = pd.DataFrame({'l1':l1, 'l2':l2, 'l3':l3, 'l4':l4, 'l5':l5, 'l6':l6})
#       9 df
#
# ~/anaconda3/envs/merlin/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/merlin/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
total = []
def append_unique(path, total):
    l = os.listdir(path)
    for el in l1:
        if el not in total:
            total.append(f'{path}/{el}')
    return total 

total = append_unique('../data/июль-ноябрь', total)
total = append_unique('../data/результат с фото', total)
total = append_unique('../data/Результаты 19-20', total)
total = append_unique('../data/результаты 07.19-31.03 - с фото/октябрь-декабрь', total)
total = append_unique('../data/результаты 07.19-31.03 - с фото/январь-март', total)
total = append_unique('../data/результаты 07.19-31.03 - с фото/июль-сентябрь', total)
len(total)
# Out:
# 5916

# %%
all_ = l1 + l2 + l3 + l4 + l5 + l6
# Out:
# ['63219-39006_49363450-d9f8-11e9-997d-00155d2d0507',
#  '63419-39007_cf6a1ebb-d945-11e9-997d-00155d2d0507',
#  '61219-40006_007dd868-52c0-11e5-a760-f01fafe92f9d',
#  '61619-40003_d1597544-b947-11e7-80e6-000c293676f4',
#  '63719-42001_d4af422a-d362-11e7-80e7-000c293676f4',
#  '61519-43022_db729364-f24c-11e9-997d-00155d2d0507',
#  '63719-44013_bee9fa7a-df46-11e9-997d-00155d2d0507',
#  '61819-41014_6f6490ff-e59a-11e9-997d-00155d2d0507',
#  '60619-41002_96f499bb-e334-11e9-997d-00155d2d0507',
#  '61919-40006_b8f939b5-73ed-11e6-be7f-f01fafe92f9d',
#  '63219-43005_f7c05e66-4330-11e6-9da2-f01fafe92f9d',
#  '63419-39021_614bae3a-f696-11e7-80eb-000c293676f4',
#  '61319-32032_0ce5f1ff-8ba3-11e7-80e6-000c293676f4',
#  '63919-42007_f3b1dfd3-ac80-11e9-997a-00155d2d0507',
#  '63419-38005_c2bb50a6-1989-11e9-9973-00155d2d0507',
#  '63919-43016_0d93cf62-f019-11e9-997d-00155d2d0507',
#  '63819-46004_a0ba8e5a-c983-11e5-8977-f01fafe92f9d',
#  '61319-33016_a0ba8e5a-c983-11e5-8977-f01fafe92f9d',
# ...

# %%
len([i for i in l4 if i not in l3])
# Out:
# 204

# %%
len(l4)
# Out:
# 1280

# %%
os.listdir('../data/результаты 07.19-31.03 - с фото/')
# Out:
# ['октябрь-декабрь', 'январь-март', 'июль-сентябрь']
